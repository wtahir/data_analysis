# %%
import json

# %%
# with open("/home/waqas/repos/platform-client/insured_object-VIE-Storm_failed.json") as f:
#     data = json.load(f)
# data["items"]

with open("/home/waqas/repos/platform-client/pipi.json") as f:
    data = json.load(f)
data["items"]
# Out:
# [{'annotation_status': 'ANNOTATED',
#   'collection_id': '446d37f1-9d7e-4935-8f9f-2e4acf0161e3',
#   'created_date': '2022-07-18T13:07:30.925484',
#   'document_id': '48ecf39e-6383-463a-b9ad-f6630f567053',
#   'file_name': '20221024636.pdf',
#   'revision_number': 0,
#   'status': 'REVIEWED'},
#  {'annotation_status': 'ANNOTATED',
#   'collection_id': '446d37f1-9d7e-4935-8f9f-2e4acf0161e3',
#   'created_date': '2022-07-18T13:07:30.379514',
#   'document_id': '8e15cbb6-5871-42db-b390-b615b936970e',
#   'file_name': '20221024604.pdf',
#   'revision_number': 0,
#   'status': 'REVIEWED'},
#  {'annotation_status': 'ANNOTATED',
#   'collection_id': '446d37f1-9d7e-4935-8f9f-2e4acf0161e3',
#   'created_date': '2022-07-18T13:07:30.199911',
#   'document_id': 'f37160fe-10d2-41ca-b15a-1bc3978d7403',
#   'file_name': '20221024458.pdf',
#   'revision_number': 0,
#   'status': 'REVIEWED'},
#  {'annotation_status': 'ANNOTATED',
#   'collection_id': '446d37f1-9d7e-4935-8f9f-2e4acf0161e3',
# ...

# %%
li = []
for i in data["items"]:
    if i["annotation_status"] == "ANNOTATED":
        print(i["file_name"])
        li.append(i["file_name"])
# Out:
# 20221024636.pdf
# 20221024604.pdf
# 20221024458.pdf
# 20221024431.pdf
# 20221024428.pdf
# 20221024332.pdf
# 20221024327.pdf
# 20221024288.pdf
# 20221024278.pdf
# 20221024208.pdf
# 20221024147.pdf
# 20221024036.pdf
# 20221024033.pdf
# 20221023975.pdf
# 20221023969.pdf
# 20221023968.pdf
# 20221023794.pdf
# 20221023736.pdf
# 20221023655.pdf
# 20221023638.pdf
# 20221023622.pdf
# 20221023608.pdf
# 20221023444.pdf
# 20221023270.pdf
# 20221023196.pdf
# 20221023180.pdf
# 20221023170.pdf
# 20221023074.pdf
# 20221023065.pdf
# 20221023018.pdf
# 20221022989.pdf
# 20221022986.pdf
# 20221022982.pdf
# 20221022975.pdf
# 20221022853.pdf
# 20221022851.pdf
# 20221022844.pdf
# 20221022822.pdf
# 20221022736.pdf
# 20221022728.pdf
# 20221022622.pdf
# 20221022597.pdf
# 20221022561.pdf
# 20221022505.pdf
# 20221022489.pdf
# 20221022481.pdf
# 20221022477.pdf
# 20221022474.pdf
# 20221022428.pdf
# 20221022285.pdf
# 20221022270.pdf
# 20221022268.pdf
# 20221022265.pdf
# 20221022252.pdf
# 20221022187.pdf
# ...

# %%
len(li)
# Out:
# 157
