# %%
import pagexml
import glob
import csv
import json

# %%
files = glob.glob('/home/waqas/LOB/water_model_xmls/cq_water_UNQ_test_pr_xmls/*.xml')

# %%
def create_tab_files(files_path, tabfile_name, question_uuid, json_file, gt_or_pr):
    li_files = []
    li_class = []
    li_conf = []
    
    with open(json_file) as f:
        data = json.load(f)
    
    for i in data:   
        for j in i['answers']:
            for xml in files_path:
                pxml = pagexml.PageXML(xml)
                file_name = pxml.getValue('/_:PcGts/_:Property[@key="fileName"]/@value')
                node = pxml.selectNth('//_:PcGts', 0)
                conf = pxml.getValue(f'/_:PcGts/_:Property[@key="{question_uuid}"]/@conf')
                class_ = pxml.getValue(f'/_:PcGts/_:Property[@key="{question_uuid}"]/@value')

                if class_[7:] == j['id']:
                    class_ = j['answer']

                    li_files.append(file_name)
                    li_class.append(class_)
                    li_conf.append(conf)
                    
            if gt_or_pr == 'pr':
                with open('pr_' + tabfile_name + '.tab', 'w') as f:
                    writer = csv.writer(f, delimiter='\t')
                    writer.writerows(zip(li_files, li_conf, li_class))
            
            if gt_or_pr == 'gt':
                with open('gt_' + tabfile_name + '.tab', 'w') as f:
                    writer = csv.writer(f, delimiter='\t')
                    writer.writerows(zip(li_files, li_class))

# %%
create_tab_files(files_path=files, tabfile_name= 'building_rooms_heated',
                question_uuid= 'question_a0cd7412-b95d-498f-8f28-2fc6e0688ed8',
                json_file = '../water.json', gt_or_pr = 'pr')

# %%
create_tab_files(files_path=files, tabfile_name= 'which_pipe_water_leak', 
                question_uuid= 'question_ea02bf83-3ace-4cf9-ab8c-fa6d2659b81e',
                json_file = '../water.json', gt_or_pr = 'pr')

# %%
create_tab_files(files_path=files, tabfile_name= 'fracture_or_frost_point_location',
                question_uuid= 'question_ee32df24-7127-4397-942d-8e61a663618f',
                json_file = '../water.json', gt_or_pr = 'pr')

# %%
create_tab_files(files_path=files, tabfile_name= 'if_damage_flooring_then_type_flooring',
                question_uuid= 'question_75ba7f26-fd21-458d-995b-f25c0147836d',
                json_file = '../water.json', gt_or_pr = 'pr')

# %%
create_tab_files(files_path=files, tabfile_name= 'if_damage_to_flooring_Was_flooring_purchased_by_policyholder',
                question_uuid= 'question_a781fc66-704e-4828-889d-3c5743f34d52',
                json_file = '../water.json', gt_or_pr = 'pr')

# %%
create_tab_files(files_path=files, tabfile_name= 'if_damage_to_flooring_subfloor_location',
                question_uuid= 'question_36f9b610-40ff-445c-97a7-e3211c157fc9',
                json_file = '../water.json', gt_or_pr = 'pr')

# %%
create_tab_files(files_path=files, tabfile_name= 'installations_purchased_by_policyholder',
                question_uuid= 'question_c163f370-a6d1-449b-82b6-c19f3dd88ecf',
                json_file = '../water.json', gt_or_pr = 'pr')

# %%
create_tab_files(files_path=files, tabfile_name= 'water-carrying_systems_shut_off',
                question_uuid= 'question_7da905e9-39a2-4286-9f89-0a73d552ec8a',
                json_file = '../water.json', gt_or_pr = 'pr')

# %%
create_tab_files(files_path=files, tabfile_name= 'damage_site',
                question_uuid= 'question_2cf6eaaf-4a4e-477f-b71f-2fd537ad7be3',
                json_file = '../water.json', gt_or_pr = 'pr')

# %%
create_tab_files(files_path=files, tabfile_name= 'building_unused',
                question_uuid= 'question_682db97e-4568-433b-8efe-194e6b564a20',
                json_file = '../water.json', gt_or_pr = 'pr')

# %%
# with open('../water.json') as f:
#     data = json.load(f)

# question_uuid = 'ea02bf83-3ace-4cf9-ab8c-fa6d2659b81e'
# for i in data:   
#     for j in i['answers']:
#         for xml in files:
#                 pxml = pagexml.PageXML(xml)
#                 file_name = pxml.getValue('/_:PcGts/_:Property[@key="fileName"]/@value')
#                 node = pxml.selectNth('//_:PcGts', 0)
#                 conf = pxml.getValue('/_:PcGts/_:Property[@key="question_ea02bf83-3ace-4cf9-ab8c-fa6d2659b81e"]/@conf')              
#                 class_ = pxml.getValue('/_:PcGts/_:Property[@key="question_2cf6eaaf-4a4e-477f-b71f-2fd537ad7be3"]/@value')
# #                 print(file_name)
#                 print(class_[7:])
        

# #                 if class_[7:] == j['id']:
# #                     class_ = j['answer']
# #                     print(class_, ' ', j['answer'])
# Out:
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# d7bc6d9b-2be3-44d9-a110-4db6c328672c
# ...
