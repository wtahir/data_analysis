# %%
import glob
import shutil

# %%
p = glob.glob('/home/waqas/mnt/VIE002/250_water_converted/*.eml')



for i in p:
    name = i[43:53]
    for subdir in glob.glob('/home/waqas/mnt/VIE002/250_water_converted/*'):
        folder = subdir[43:]
        if name == folder:
            shutil.move(i, subdir)

# %%
for subdir in glob.glob('/home/waqas/mnt/VIE002/250_water_converted/*/*.eml'):
    print(len(subdir))
# Out:
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# 111
# ...
