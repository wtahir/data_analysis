# %%
import pagexml
import pandas as pd
import glob
import os
from tqdm import tqdm

# %%
files = glob.glob('/home/waqas/repos/platform-client/platform_client/risks_collection/risks_car-accident-unq_train/*.xml')

# c = 0

li = []
for xml in files:
        pxml = pagexml.PageXML(xml)
        
        class_name = pxml.getValue('/_:PcGts/_:Property[@key="class"]/@value')
        
#         class_name = pxml.getValue('/_:PcGts/_:Property[@key="question_2"]/@value')
        
        file_name = pxml.getValue('/_:PcGts/_:Property[@key="fileName"]/@value')
        
        uuid = pxml.getValue('/_:PcGts/_:Property[@key="uuid"]/@value')
        
        node = pxml.selectNth('/_:PcGts/_:Property[@key="class"]')
        
#         node = pxml.selectNth('/_:PcGts/_:Property[@key="class"]')
#        
        node_ = pxml.selectNth('//_:PcGts', 0)
        
        
#         if class_name == "DozxNOHS-echo-1Wzr-2w6B-c1lCBYBiLOUq":
#            print(file_name)
            
#             pxml.rmElem(node)
        pxml.setProperty(node_, 'class', 'fz3mkK04-echo-5DzM-2Dxl-ubDt54NGrdxh')
        pxml.write(xml)
#             print(uuid)
    
# #             c = c+1
            
#         elif class_name == "t9V6OpZY-echo-4vH2-2YyF-HRCPZWC8Lphl":
# #             pxml.rmElem(node)
# #             pxml.setProperty(node_, 'class', 'zwxmKHw1-echo-4DBA-5BM2-19mCC2VT70Is')
# #             pxml.write(xml)
#             print(file_name, 'heck')
            
#         elif class_name == "3XzhX8Ku-echo-4AbR-4F02-lJuRispVJ32T":
# #             pxml.rmElem(node)
# #             pxml.setProperty(node_, 'class', 'tMLcEPv6-echo-1Rf3-1rf3-1oN6CZZnnpcm')
# #             pxml.write(xml)
#             print(file_name, 'seiten')
            
#         elif class_name == "0o5KiZYK-echo-1MOp-5dFV-5lXI3lY9rrU4":
# #             pxml.rmElem(node)
# #             pxml.setProperty(node_, 'class', 'EScXIopP-echo-3g1p-1qBX-sigC8fEXXItJ')
# #             pxml.write(xml)
#             print(file_name, 'hebedach')
        
# #         elif class_name == "jaMPDezo-echo-41ul-55ny-Mij7Ag0O9zOS":
# #             pxml.rmElem(node)
# #             pxml.setProperty(node_, 'class', '9a0e59fd-44a2-4ed6-b9f8-fc2818be4b89')
# #             pxml.write(xml)
# #             print(file_name, 'scheinwerfer')
            
        
            
#             pxml.setProperty(node, 'question_1', q1)
#             pxml.setProperty(node, 'question_2', q2)
#             pxml.setProperty(node, 'question_3', q3)
#             pxml.setProperty(node, 'question_4', q4)
#             pxml.setProperty(node, 'question_5', q5)
#             pxml.write(xml)

# %%
files = glob.glob('/home/waqas/repos/platform-client/examples/natasha_annotations_uuids/*/*.xml')

# c = 0

li = []
for xml in files:
        pxml = pagexml.PageXML(xml)
        
        class_name = pxml.getValue('/_:PcGts/_:Property[@key="question_fa14a344-7f51-4e5c-b526-a81e589da78a"]/@value')
        
        file_name = pxml.getValue('/_:PcGts/_:Property[@key="uuid"]/@value')
        
        node = pxml.selectNth('/_:PcGts/_:Property[@key="question_fa14a344-7f51-4e5c-b526-a81e589da78a"]')
        
        size = pxml.selectNth('/_:PcGts/_:Property[@key="size_glass"]')
        
        size_value = pxml.getValue('/_:PcGts/_:Property[@key="question_f663a689-3e35-484f-8d7c-f9df0d87178f"]/@value')
        
        if class_name == "answer_6ec4206d-fb94-4763-b0e6-a9f20ee6e53a":
            print(file_name)
            pxml.rmElem(node)
        
        if size_value == "answer_1dd99b39-bda5-45ca-9b47-fd142bfc6c3d":
            print(file_name)
            pxml.rmElem(size)
            
        pxml.write(xml)
# Out:
# e65adaeb-f83b-42ac-b609-4de29ba72496
# add63fc7-1b70-4078-ba70-07e7da501715
# 4de22973-026b-4c3e-adae-8800926c4cc1
# 0fb009aa-6609-4296-bb53-e96b44dd6dc9
# c8f09fec-2f8b-42f1-8303-a64006e9933b
# a78ac2c8-9685-4caa-835e-4e0c0acad61d
# a78ac2c8-9685-4caa-835e-4e0c0acad61d
# 4c0e303b-6fae-4272-a4e7-c5400a58b8ef
# 24c539dd-5b14-41fe-a3ed-cb225ca39b83
# f7c2c2fb-6fe1-4fa1-9fc5-fee7f80337bc
# 7b214415-9edc-4990-8094-b96a9da4f9c0
# 4fda926e-e2bd-44af-95c8-1d5c9c96b1a1
# 13e80e06-4818-4c4a-a76c-c73e0613a035
# 13e80e06-4818-4c4a-a76c-c73e0613a035
# ac9715d7-4470-461a-aa9e-a8a01ad3c8f2
# ab3af0e3-908f-4e8f-bec6-ebd4ea2847f0
# f082b153-9bfe-4667-9e4e-6422819b842f
# a843e1b7-cec0-4d7b-8fa8-29b61bb845f2
# a6cfdc15-05dd-4597-88cf-fcc2f3e577a4
# 9ef32c7b-f6cf-4ad6-b082-208472a467c8
# 390af7e3-86f1-4d5c-a667-ed823a747776
# 2b74eced-9ca3-4072-8d07-54ca4e8e365e
# e97b8919-f92c-4510-94bf-e2422190946b
# dee697ae-3559-4ff6-80b6-9734c2ba43e4
# f59300e1-210b-4a55-8c46-77875537e064
# ...

# %%
import uuid

uuid.uuid4()
# Out:
# UUID('eb995679-1e41-4f9d-bea2-eba5fc6fc1c7')

# %%
li = ['<= 5',
      '> 5, <= 10',
      '> 10, <= 12',
      '> 12',
      'Nicht beantwortbar',
      'Nicht relevant',
      'zerbrochen',
      'zerkratzt',
      'Wohnung / Eigenheim des VN',
      '',
      
      
    
]

# %%
files = glob.glob('/home/waqas/repos/platform-client/msa-testing-validated_xmlsFix/*.xml')


for xml in files:
    
        pxml = pagexml.PageXML(xml)
        
#         que = pxml.getValue('/_:PcGts/_:Property[@conf]/@value')
        
#         uuid = pxml.getValue('/_:PcGts/_:Property[@key="uuid"]/@value')
        
        node = pxml.selectNth('/_:PcGts/_:Property[@key="question_5"]')
        
#         que = pxml.getValue('/_:PcGts/_:Property[@conf="1"]')

        val = pxml.getValue('/_:PcGts/_:Property[@key="question_5"]/@value')

    
        if val == "Wohnung / Eigenheim des VN":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
        
        if val == "<= 5":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        if val == "> 5, <= 10":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        if val == "<= 5":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
        
        if val == "> 10, <= 12":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
        
        if val == "> 12":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
        
        if val == "zerbrochen":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
        
        if val == "zerkratzt":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
        
        if val == "andere":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        if val == "Gemeinschaftlich genutzte Bereiche im Haus des VN (z.B. Flur, Keller)":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
        
        if val == "Grundst�ck des VN (drau�en)":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
        
        if val == "Wohnung eines Kindes des VN in Ausbildung":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        if val == "Nicht beantwortbar":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        
        if val == "Vorsatz":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        if val == "während eines Umzugs":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        if val == "während Reparaturarbeiten":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        if val == "während Reparaturarbeiten":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        if val == "Ja":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        if val == "Nein":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
            
        if val == "Nicht relevant":
            pxml.rmElem(node)
            pxml.write(xml)
            print(xml)
        
        
            
        
            
        
        
        
        
#         node = pxml.selectNth('/_:PcGts/_:Property[@key="class"]')
#        
#         node_ = pxml.selectNth('//_:PcGts', 0)
    
    
        
        
#         if que <= 1:
#             print(xml)
            
            
#             pxml.rmElem(node)
# #             pxml.setProperty(node_, '4d813bf9-9c81-410a-b1c0-fe93d1e2a7eb', '7919b58c-e5ab-4d54-aa23-2c9b6afc9c47')
#             pxml.write(xml)
#         if que == "zerbrochen":
            
#             pxml.rmElem(node)
            
#             pxml.write(xml)
# Out:
# /home/waqas/repos/platform-client/msa-testing-validated_xmlsFix/34191931-6fb4-41fd-8735-81aa613a39b4.xml
# /home/waqas/repos/platform-client/msa-testing-validated_xmlsFix/056823ef-83e9-4ebb-99bd-2b0b93458eec.xml
# /home/waqas/repos/platform-client/msa-testing-validated_xmlsFix/e36c01f7-2e92-4f87-b9a3-c7701224e450.xml
# /home/waqas/repos/platform-client/msa-testing-validated_xmlsFix/6436eb4d-8aec-4290-a8e5-60ef07445291.xml
# /home/waqas/repos/platform-client/msa-testing-validated_xmlsFix/71a1dded-6d94-413a-8bb9-14b83c2da7f4.xml
# /home/waqas/repos/platform-client/msa-testing-validated_xmlsFix/892553c0-606e-4895-8b0a-c7b93d4608d0.xml
# /home/waqas/repos/platform-client/msa-testing-validated_xmlsFix/432e8852-61fc-4996-8d13-28869ec572e4.xml
# /home/waqas/repos/platform-client/msa-testing-validated_xmlsFix/12ccdea0-df2f-4dd1-b41a-eb195bc5a4ee.xml
# /home/waqas/repos/platform-client/msa-testing-validated_xmlsFix/ff9c20d3-c44a-4906-b27c-a887df0ea619.xml
# ...
