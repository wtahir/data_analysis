# %%
import pandas as pd

# %%
# df = pd.read_excel (r'/home/waqas/LOB/q&a_v3/coverage_check_question_annotation.csv')

df = pd.read_excel(r'/home/waqas/LOB/q&a_v3/coverage_check_question_annotation.xlsx')
df = df[df['Zustand'].notnull()]

# %%
# df.info()

# %%
cols = df.columns

# %%
cols = cols[2:7]

ans = []

for col in cols:
    ans.append(df[col].value_counts(ascending=False))
#     print(col)
#     print(df[col].value_counts())
    
yo = pd.DataFrame(ans)

# %%
yo = yo.T
yo.fillna(0)
# Out:
#                                                     Größe des Glases (m²)  \
# Nicht relevant                                                      153.0
# <= 5                                                                111.0
# Nicht beantwortbar                                                   87.0
# > 5, <= 10                                                            3.0
# > 12                                                                  1.0
# nicht beantwortbar                                                    1.0
# zerbrochen                                                            0.0
# zerkratzt                                                             0.0
# Wohnung / Eigenheim des VN                                            0.0
# andere                                                                0.0
# Grundstück des VN (draußen)                                           0.0
# Wohnung eines Kindes des VN in Ausbildung                             0.0
# ...

# %%
df = pd.read_excel('/home/waqas/LOB/q&a_v2/coverage_check_question_annotation.xlsx')
df = df[df['Zustand'].notnull()]

# %%
cols = df.columns

# %%
cols = cols[2:7]

ans = []

for col in cols:
    ans.append(df[col].value_counts(ascending=False))
#     print(col)
#     print(df[col].value_counts())
    
v2 = pd.DataFrame(ans)
v2 = v2.T
v2.fillna(0)
# Out:
#                                                     Glass size (sq.m)  \
# Nicht relevant                                                  143.0
# <= 5                                                             16.0
# Nicht beantwortbar                                                8.0
# > 12                                                              1.0
# zerbrochen                                                        0.0
# zerkratzt                                                         0.0
# Wohnung / Eigenheim des VN                                        0.0
# Grundstück des VN (draußen)                                       0.0
# andere                                                            0.0
# Gemeinschaftlich genutzte Bereiche im Haus des ...                0.0
# während eines Umzugs                                              0.0
# Ja                                                                0.0
#
# ...
